# %%
import pandas as pd

print("Hello World")
# Out:
# Failed to start the Kernel.
#
# PermissionError: [WinError 5] Access is denied: 'C:\\Users\\saini\\.ipython'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
